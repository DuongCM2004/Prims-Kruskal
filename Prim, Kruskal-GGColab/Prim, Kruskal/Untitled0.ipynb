# %%
import sys
import random
import timeit
import numpy as np
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %run 'https://colab.research.google.com/drive/1aa8BX7NJcbp4XK-lVGiRPuqGn6cdniZd?usp=drive_link'
# %run 'https://colab.research.google.com/drive/1nSdnbHo6spC8MOmZbM8JPWK8XH6Yn8Yw?usp=drive_link'
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     713             fpath = arg_lst[0]
# --> 714             filename = file_finder(fpath)
#     715         except IndexError:
#
# /usr/local/lib/python3.10/dist-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'https://colab.research.google.com/drive/1aa8BX7NJcbp4XK-lVGiRPuqGn6cdniZd?usp=drive_link.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-11-22c976db7634> in <cell line: 1>()
# ...

# %%
start = timeit.default_timer()
if __name__ == "__main__":
    num_vertices = 15
    dense_graph = generate_dense_graph(num_vertices)

    print("Dense Graph (Adjacency Matrix):")
    for row in dense_graph:
        print(row)

    # Compute MST using Prim's algorithm
    mst = prim(dense_graph)
    print("\nMinimum Spanning Tree (MST):")
    print("Edge \t Weight")
    min_sum = 0
    for i in range(1, len(mst)):
        print(f"{mst[i]} - {i} \t {dense_graph[i][mst[i]]}")
        min_sum += dense_graph[i][mst[i]]
    print('Sum: ', min_sum)
stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-43fd5a74b23c> in <cell line: 2>()
#       2 if __name__ == "__main__":
#       3     num_vertices = 15
# ----> 4     dense_graph = generate_dense_graph(num_vertices)
#       5
#       6     print("Dense Graph (Adjacency Matrix):")
#
# NameError: name 'generate_dense_graph' is not defined
